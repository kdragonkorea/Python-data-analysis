# %%
import urllib
print(urllib.parse.quote('가나다ABC123'))
print(urllib.parse.quote_plus('가나다ABC123'))
print(urllib.parse.quote('가나다 ABC123')) # 빈칸(공백)을 '%20'로 출력
print(urllib.parse.quote_plus('가나다 ABC123')) # 빈칸(공백)을 '+'로 출력
# Out:
# %EA%B0%80%EB%82%98%EB%8B%A4ABC123
# %EA%B0%80%EB%82%98%EB%8B%A4ABC123
# %EA%B0%80%EB%82%98%EB%8B%A4%20ABC123
# %EA%B0%80%EB%82%98%EB%8B%A4+ABC123

# %%
query_str1 = "q="+urllib.parse.quote('가나다')
query_str2 = "q="+urllib.parse.quote_plus('가나다')
query_str3 = urllib.parse.urlencode({"q" : "가나다"})
print("-------------------------------------------")
print(query_str1)
print(query_str2)
print(query_str3)
# Out:
# -------------------------------------------
# q=%EA%B0%80%EB%82%98%EB%8B%A4
# q=%EA%B0%80%EB%82%98%EB%8B%A4
# q=%EA%B0%80%EB%82%98%EB%8B%A4

# %%
from bs4 import BeautifulSoup
import urllib.request as req

busNum = '360'
key = '%2BjzsSyNtwmcqxUsGnflvs3rW2oceFvhHR8AFkM3ao%2Fw50hwHXgGyPVutXw04uAXvrkoWgkoScvvhlH7jgD4%2FRQ%3D%3D'
url1 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?serviceKey='+key+'&strSrch='+busNum
res = req.urlopen(url1)

soup = BeautifulSoup(res.read().decode('utf-8'), features="xml") # xml은 100% utf-8

busRouteId = None
for itemList in soup.find_all('itemList') :
    busRouteId = itemList.find('busRouteId').string
    busRouteNm = itemList.find('busRouteNm').string
    if busRouteNm == busNum :
        break

url2 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey='+key+'&busRouteId='+busRouteId
res = req.urlopen(url2)
soup = BeautifulSoup(res.read().decode('utf-8'), features="xml")

busPos = []
for itemList in soup.find_all('itemList') :
    gpsY = itemList.find('gpsY').string
    gpsX = itemList.find('gpsX').string

    busPos.append((gpsY, gpsX))

print('[ ' + busNum + '번 버스의 운행 위치 ]')
if len(busPos) != 0 :
    print(busNum + '번 버스 ' + str(len(busPos)) + '대 운행중...')
    for lat,lng in busPos :
        print(lat+','+lng)
else :
    print('현재 운행중인 ' + busNum + '번 버스가 없어요...')
# Out:
# [ 360번 버스의 운행 위치 ]
# 360번 버스 91대 운행중...
# 37.4699297672,127.1275897549
# 37.4790433896,127.1261237834
# 37.482125,127.124748
# 37.4883648963,127.1213627915
# 37.4943822012,127.1171609467
# 37.5002084826,127.1118384337
# 37.5034082968,127.1089442853
# 37.5068001738,127.1058262006
# 37.5128993133,127.0979457604
# 37.5122132454,127.0939144028
# 37.5117722886,127.0872805398
# 37.5118706155,127.0833904794
# 37.512009235,127.0796916235
# 37.5111175337,127.0720732937
# 37.5099462683,127.0657996068
# 37.5086670057,127.0617005963
# 37.5066831874,127.0554269279
# 37.505143,127.050205
# 37.503232,127.044057
# 37.5015409767,127.0386328674
# 37.5004418394,127.0350786317
# 37.4988294041,127.0298390986
# 37.500785,127.02637
# 37.506367,127.023728
# 37.5106480618,127.0192203041
# 37.5083418804,127.0121292217
# 37.5062923789,127.0052834138
# 37.5034152049,126.9958263651
# 37.5019451598,126.9900264523
# 37.503188597,126.9766525988
# 37.505867,126.971748
# 37.5064370015,126.9685844969
# 37.5075850724,126.9655921789
# 37.5115728985,126.9612375315
# 37.512734203,126.9509621786
# 37.5138325876,126.9447114504
# 37.5134800797,126.9388655754
# 37.5132368488,126.9323737344
# 37.5130048235,126.9242224384
# 37.5140830291,126.9195131812
# 37.516815,126.916956
# 37.5218906273,126.9188836862
# 37.5254720914,126.9241508208
# 37.5269560563,126.9270250084
# 37.5273043795,126.9316210834
# 37.5259920176,126.9309977447
# 37.5250045778,126.9281836353
# 37.5260593379,126.9246697181
# 37.523605,126.920262
# 37.5183978581,126.9148883495
# 37.5167591036,126.9166368877
# 37.5136409433,126.9200351486
# 37.512907,126.923495
# 37.513174,126.931437
# 37.513423,126.938456
# 37.513733,126.943811
# 37.512825,126.949256
# 37.5130085949,126.9567458811
# 37.511297,126.96101
# 37.5074984059,126.9650447528
# 37.5063016864,126.9680257853
# 37.5054978005,126.9711242049
# 37.5024209111,126.9769231591
# 37.5016386844,126.9888988467
# 37.5029429707,126.9944510234
# 37.5057382586,127.003792583
# 37.5079040519,127.0110398687
# 37.510420605,127.0196823939
# 37.5072264964,127.0230319441
# 37.501817,127.025438
# 37.4981357274,127.0291477897
# 37.4995717499,127.0337900061
# 37.501137,127.038818
# 37.502783,127.044247
# 37.5047611955,127.050462265
# 37.506043,127.054803
# 37.5081065399,127.0616639386
# 37.5095036021,127.0660087348
# 37.5104187252,127.0728158016
# 37.5116128425,127.0795554593
# 37.5114066648,127.0844951326
# 37.5115116112,127.0912020656
# 37.51241161,127.0981962498
# 37.507105259,127.1052520216
# 37.5036628588,127.108453771
# 37.5005992316,127.111232788
# 37.4947387984,127.1164919903
# 37.48901,127.120775
# 37.48309,127.123873
# 37.479907,127.125472
# 37.470728,127.128144

# %%
from bs4 import BeautifulSoup
import urllib.request as req

key = '796143536a756e69313134667752417a'
contentType = 'xml'
startIndex = '1'
endIndex = '10'
url = 'http://openapi.seoul.go.kr:8088/'+key+'/'+contentType+'/LampScpgmtb/'+startIndex+'/'+endIndex+'/'
savename = 'output/edu.xml'
req.urlretrieve(url, savename)

xml = open(savename, 'r', encoding='utf-8').read()

soup = BeautifulSoup(xml, 'xml')

pjList = []

for itemList in soup.find_all('row') :
    up_nm = itemList.find('UP_NM').string
    up_nm = '없음' if up_nm is None else up_nm
    pgm_nm = itemList.find('PGM_NM').string
    pgm_nm = '없음' if pgm_nm is None else pgm_nm
    target_nm = itemList.find('TARGET_NM').string
    target_nm = '없음' if target_nm is None else target_nm
    u_price = itemList.find('U_PRICE').string
    u_price = '없음' if u_price is None else u_price
    pjList.append((up_nm, pgm_nm, target_nm, u_price)) # 튜플로 설정

print('[ 서울 청소년 수련관 강좌 리스트 ]')
for up_nm, pgm_nm, target_nm, u_price in pjList :
    print(up_nm+','+pgm_nm+','+target_nm+','+str(u_price))
# Out:
# [<row>
#  <UP_ID>04</UP_ID>
#  <UP_NM>금천청소년수련관</UP_NM>
#  <SALE_COM_CD>11</SALE_COM_CD>
#  <SALE_COM_NM>생활체육사업수입</SALE_COM_NM>
#  <BAS_CD>01</BAS_CD>
#  <BAS_NM>생활체육프로그램</BAS_NM>
#  <ITEM_CD>010011</ITEM_CD>
#  <ITEM_NM>수영사업</ITEM_NM>
#  <CLS_CD>000006</CLS_CD>
#  <CLS_NM>조기건강수영</CLS_NM>
#  <PGM_CD>010700307</PGM_CD>
#  <PGM_NM>아침B-청소년</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>O9</TARGET_CD>
#  <TARGET_NM>주2회수영-청소년(구)</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>0700</START_T>
#  <END_T>0750</END_T>
#  <AREA_CD>01</AREA_CD>
#  <U_PRICE>36000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>0101000</DT_WEEK_CD>
#  <RGL_QTY>10</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>04</UP_ID>
#  <UP_NM>금천청소년수련관</UP_NM>
#  <SALE_COM_CD>11</SALE_COM_CD>
#  <SALE_COM_NM>생활체육사업수입</SALE_COM_NM>
#  <BAS_CD>01</BAS_CD>
#  <BAS_NM>생활체육프로그램</BAS_NM>
#  <ITEM_CD>010011</ITEM_CD>
#  <ITEM_NM>수영</ITEM_NM>
#  <CLS_CD>000005</CLS_CD>
#  <CLS_NM>여성수영교실</CLS_NM>
#  <PGM_CD>011000414</PGM_CD>
#  <PGM_NM>난초A</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202001</YYMM>
#  <TARGET_CD>32</TARGET_CD>
#  <TARGET_NM>초4~24세미만</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1000</START_T>
#  <END_T>1050</END_T>
#  <AREA_CD>01</AREA_CD>
#  <U_PRICE>41000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>1010100</DT_WEEK_CD>
#  <RGL_QTY>90</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>04</UP_ID>
#  <UP_NM>금천청소년수련관</UP_NM>
#  <SALE_COM_CD>11</SALE_COM_CD>
#  <SALE_COM_NM>생활체육사업수입</SALE_COM_NM>
#  <BAS_CD>01</BAS_CD>
#  <BAS_NM>생활체육프로그램</BAS_NM>
#  <ITEM_CD>010011</ITEM_CD>
#  <ITEM_NM>수영사업</ITEM_NM>
#  <CLS_CD>000006</CLS_CD>
#  <CLS_NM>조기건강수영</CLS_NM>
#  <PGM_CD>010700309</PGM_CD>
#  <PGM_NM>아침C(5회)-청소년</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>P6</TARGET_CD>
#  <TARGET_NM>주5회수영-청소년(구)</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>0700</START_T>
#  <END_T>0750</END_T>
#  <AREA_CD>01</AREA_CD>
#  <U_PRICE>56000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>1111100</DT_WEEK_CD>
#  <RGL_QTY>5</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>19</SALE_COM_CD>
#  <SALE_COM_NM>목적사업수입</SALE_COM_NM>
#  <BAS_CD>05</BAS_CD>
#  <BAS_NM>목적사업</BAS_NM>
#  <ITEM_CD>050028</ITEM_CD>
#  <ITEM_NM>(2019)동네학교(교육문화)</ITEM_NM>
#  <CLS_CD>000005</CLS_CD>
#  <CLS_NM>음악클래스</CLS_NM>
#  <PGM_CD>051000155</PGM_CD>
#  <PGM_NM>경기민요와 장구 A</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>01</TARGET_CD>
#  <TARGET_NM>7세~초등</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1000</START_T>
#  <END_T>1050</END_T>
#  <AREA_CD>07</AREA_CD>
#  <U_PRICE>40000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT>20200101</REAL_ST_DT>
#  <REAL_ED_DT>20200131</REAL_ED_DT>
#  <DT_WEEK_CD>0000010</DT_WEEK_CD>
#  <RGL_QTY>10</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>10</SALE_COM_CD>
#  <SALE_COM_NM>교육문화사업수입</SALE_COM_NM>
#  <BAS_CD>01</BAS_CD>
#  <BAS_NM>교육문화</BAS_NM>
#  <ITEM_CD>010023</ITEM_CD>
#  <ITEM_NM>(2019)성인클래스</ITEM_NM>
#  <CLS_CD>000016</CLS_CD>
#  <CLS_NM>지도사</CLS_NM>
#  <PGM_CD>011000529</PGM_CD>
#  <PGM_NM>국가공인 한자지도사</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>25</TARGET_CD>
#  <TARGET_NM>성인</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1000</START_T>
#  <END_T>1150</END_T>
#  <AREA_CD>12</AREA_CD>
#  <U_PRICE>30000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>1000000</DT_WEEK_CD>
#  <RGL_QTY>15</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>19</SALE_COM_CD>
#  <SALE_COM_NM>목적사업수입</SALE_COM_NM>
#  <BAS_CD>05</BAS_CD>
#  <BAS_NM>목적사업</BAS_NM>
#  <ITEM_CD>050029</ITEM_CD>
#  <ITEM_NM>(2019)동네학교(생활체육)</ITEM_NM>
#  <CLS_CD>000002</CLS_CD>
#  <CLS_NM>체육관프로그램</CLS_NM>
#  <PGM_CD>051600047</PGM_CD>
#  <PGM_NM>기린A</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>90</TARGET_CD>
#  <TARGET_NM>초2~5</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1600</START_T>
#  <END_T>1650</END_T>
#  <AREA_CD>03</AREA_CD>
#  <U_PRICE>30000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT>00000000</REAL_ST_DT>
#  <REAL_ED_DT>00000000</REAL_ED_DT>
#  <DT_WEEK_CD>0101000</DT_WEEK_CD>
#  <RGL_QTY>25</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>19</SALE_COM_CD>
#  <SALE_COM_NM>목적사업수입</SALE_COM_NM>
#  <BAS_CD>05</BAS_CD>
#  <BAS_NM>목적사업</BAS_NM>
#  <ITEM_CD>050029</ITEM_CD>
#  <ITEM_NM>(2019)동네학교(생활체육)</ITEM_NM>
#  <CLS_CD>000001</CLS_CD>
#  <CLS_NM>수영프로그램</CLS_NM>
#  <PGM_CD>051600050</PGM_CD>
#  <PGM_NM>상어1-3(초급)</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>03</TARGET_CD>
#  <TARGET_NM>초등학생</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1600</START_T>
#  <END_T>1650</END_T>
#  <AREA_CD>01</AREA_CD>
#  <U_PRICE>40000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT>00000000</REAL_ST_DT>
#  <REAL_ED_DT>00000000</REAL_ED_DT>
#  <DT_WEEK_CD>1010100</DT_WEEK_CD>
#  <RGL_QTY>15</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>19</SALE_COM_CD>
#  <SALE_COM_NM>목적사업수입</SALE_COM_NM>
#  <BAS_CD>05</BAS_CD>
#  <BAS_NM>목적사업</BAS_NM>
#  <ITEM_CD>050028</ITEM_CD>
#  <ITEM_NM>(2019)동네학교(교육문화)</ITEM_NM>
#  <CLS_CD>000003</CLS_CD>
#  <CLS_NM>자기표현클래스</CLS_NM>
#  <PGM_CD>051000157</PGM_CD>
#  <PGM_NM>셀프리더쉽&amp;표현력 스피치 A</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>02</TARGET_CD>
#  <TARGET_NM>초3~6</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1000</START_T>
#  <END_T>1050</END_T>
#  <AREA_CD>29</AREA_CD>
#  <U_PRICE>33000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>0000010</DT_WEEK_CD>
#  <RGL_QTY>15</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>19</SALE_COM_CD>
#  <SALE_COM_NM>목적사업수입</SALE_COM_NM>
#  <BAS_CD>05</BAS_CD>
#  <BAS_NM>목적사업</BAS_NM>
#  <ITEM_CD>050028</ITEM_CD>
#  <ITEM_NM>(2019)동네학교(교육문화)</ITEM_NM>
#  <CLS_CD>000006</CLS_CD>
#  <CLS_NM>요리클래스</CLS_NM>
#  <PGM_CD>051800058</PGM_CD>
#  <PGM_NM>속성 제빵자격증반</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>A3</TARGET_CD>
#  <TARGET_NM>초6~성인(3개월)</TARGET_NM>
#  <MM_QTY>3</MM_QTY>
#  <START_T>1800</START_T>
#  <END_T>2200</END_T>
#  <AREA_CD>20</AREA_CD>
#  <U_PRICE>150000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT>20200101</REAL_ST_DT>
#  <REAL_ED_DT>20200131</REAL_ED_DT>
#  <DT_WEEK_CD>0010000</DT_WEEK_CD>
#  <RGL_QTY>18</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM/>
#  </row>,
#  <row>
#  <UP_ID>12</UP_ID>
#  <UP_NM>시립서대문청소년센터</UP_NM>
#  <SALE_COM_CD>10</SALE_COM_CD>
#  <SALE_COM_NM>교육문화사업수입</SALE_COM_NM>
#  <BAS_CD>01</BAS_CD>
#  <BAS_NM>교육문화</BAS_NM>
#  <ITEM_CD>010021</ITEM_CD>
#  <ITEM_NM>(2019)미술클래스</ITEM_NM>
#  <CLS_CD>000019</CLS_CD>
#  <CLS_NM>미술놀이</CLS_NM>
#  <PGM_CD>011200158</PGM_CD>
#  <PGM_NM>신나는미술세상(C)</PGM_NM>
#  <FG_CD>02</FG_CD>
#  <FG_NM>이용료</FG_NM>
#  <YYMM>202003</YYMM>
#  <TARGET_CD>39</TARGET_CD>
#  <TARGET_NM>5~6세</TARGET_NM>
#  <MM_QTY>1</MM_QTY>
#  <START_T>1200</START_T>
#  <END_T>1245</END_T>
#  <AREA_CD>06</AREA_CD>
#  <U_PRICE>30000</U_PRICE>
#  <START_DAY>01</START_DAY>
#  <REAL_ST_DT/>
#  <REAL_ED_DT/>
#  <DT_WEEK_CD>0000010</DT_WEEK_CD>
#  <RGL_QTY>15</RGL_QTY>
#  <CLOSE_YN>N</CLOSE_YN>
#  <USER_NM>강사없음</USER_NM>
#  </row>]

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

key = '796143536a756e69313134667752417a'
contentType = 'xml'
startIndex = '1'
endIndex = '100'
date = '20201010'

url = 'http://openapi.seoul.go.kr:8088/'+key+'/'+contentType+'/CardSubwayStatsNew/'+startIndex+'/'+endIndex+'/'+date+'/'
savename = 'output/subway.xml'
req.urlretrieve(url, savename) # 파일로 저장 없이 임시로 저장

xml = open(savename, 'r', encoding='utf-8').read()  # 파일로 저장 없이 임시로 저장 후 오픈
soup = BeautifulSoup(xml, 'xml')

subwayList = []
for itemList in soup.find_all('row') :
    line_num = itemList.find('LINE_NUM').string
    sub_sta_nm = itemList.find('SUB_STA_NM').string
    ride_pasgr_num = itemList.find('RIDE_PASGR_NUM').string
    alight_pasgr_num = itemList.find('ALIGHT_PASGR_NUM').string
    subwayList.append((line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num))

print('[ 서울시 지하철호선별 역별 승하차 인원 정보 ]')
for line_num, sub_sta_nm, ride_pasgr_num, alight_pasgr_num in subwayList :
    print(line_num+','+sub_sta_nm+','+ride_pasgr_num+','+alight_pasgr_num)

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

key = '4WQ7X833TXC370SUTDX4'
contentType = 'xml'
startIndex = '1'
endIndex = '100'

url = 'http://ecos.bok.or.kr/api/KeyStatisticList/'+key+'/'+contentType+'/kr/'+startIndex+'/'+endIndex+'/'
res = req.urlopen(url)

soup = BeautifulSoup(res.read().decode('utf-8'), 'xml')
ecoList = []
for itemList in soup.find_all('row') :
    class_name = itemList.find('CLASS_NAME').string
    class_name = '없음' if class_name is None else class_name
    keystat_name = itemList.find('KEYSTAT_NAME').string
    keystat_name = '없음' if keystat_name is None else keystat_name
    data_value = itemList.find('DATA_VALUE').string
    data_value = '없음' if data_value is None else data_value
    cycle = itemList.find('CYCLE').string
    cycle = '없음' if cycle is None else cycle
    unit_name = itemList.find('UNIT_NAME').string
    unit_name = '없음' if unit_name is None else unit_name
    ecoList.append((class_name, keystat_name, data_value, cycle, unit_name))

print('[ 100대 통계 지표 ]')
for class_name, keystat_name, data_value, cycle, unit_name in ecoList :
    print(class_name+','+keystat_name+','+data_value+','+cycle+','+unit_name)
# Out:
# [ 100대 통계 지표 ]
# 국민소득 · 경기 · 기업경영,경제성장률(실질, 계절조정 전기대비),1.2,202004,%
# 국민소득 · 경기 · 기업경영,민간소비증감률(실질, 계절조정 전기대비),-1.5,202004,%
# 국민소득 · 경기 · 기업경영,설비투자증감률(실질, 계절조정 전기대비),-2,202004,%
# 국민소득 · 경기 · 기업경영,건설투자증감률(실질, 계절조정 전기대비),6.5,202004,%
# 국민소득 · 경기 · 기업경영,GDP(명목, 계절조정),490139.3,202004,십억원
# 국민소득 · 경기 · 기업경영,GDP디플레이터,104.416,202004,2015=100
# 국민소득 · 경기 · 기업경영,1인당GNI,31755,2020,달러
# 국민소득 · 경기 · 기업경영,총저축률,37.2,202004,%
# 국민소득 · 경기 · 기업경영,국내총투자율,30.8,202004,%
# 국민소득 · 경기 · 기업경영,수출입의 대 GNI 비율,73.3,2020,%
# 국민소득 · 경기 · 기업경영,제조업업황실적BSI,82,202102,없음
# 국민소득 · 경기 · 기업경영,소비자심리지수,100.45528,202103,없음
# 국민소득 · 경기 · 기업경영,경제심리지수,96.56108,202102,없음
# 국민소득 · 경기 · 기업경영,경기동행지수순환변동치,99.5,202101,2015=100
# 국민소득 · 경기 · 기업경영,경기선행지수순환변동치,102.7,202101,2015=100
# 국민소득 · 경기 · 기업경영,제조업부채비율,73.49,2019,%
# 국민소득 · 경기 · 기업경영,제조업매출액세전순이익률,4.24,2019,%
# 국민소득 · 경기 · 기업경영,제조업매출액증감률,-1.72,2019,%
# 산업활동 · 소비 · 투자,전산업생산지수(농림어업제외),106.1,202101,2015=100
# 산업활동 · 소비 · 투자,제조업생산지수,108.5,202101,2015=100
# 산업활동 · 소비 · 투자,제조업출하지수,101.4,202101,2015=100
# 산업활동 · 소비 · 투자,제조업재고지수,111.6,202101,2015=100
# 산업활동 · 소비 · 투자,제조업가동률지수,96.8,202101,2015=100
# 산업활동 · 소비 · 투자,서비스업생산지수,104.6,202101,2015=100
# 산업활동 · 소비 · 투자,도소매업지수,100.5,202101,2015=100
# 산업활동 · 소비 · 투자,자동차판매업지수,119.2,202101,2015=100
# 산업활동 · 소비 · 투자,소매판매액지수,111.6,202101,2015=100
# 산업활동 · 소비 · 투자,개인신용카드사용액,52274893.737361,202012,백만원
# 산업활동 · 소비 · 투자,설비투자지수,117,202101,2015=100
# 산업활동 · 소비 · 투자,국내수요기계수주액,4069531,202012,백만원
# 산업활동 · 소비 · 투자,기계류내수출하지수,88,202101,2015=100
# 산업활동 · 소비 · 투자,건축허가면적,15440575,202012,㎡
# 산업활동 · 소비 · 투자,건축착공면적,13063740,202012,㎡
# 산업활동 · 소비 · 투자,건설수주액,11171197,202101,백만원
# 산업활동 · 소비 · 투자,건설기성액,9487397,202101,백만원
# 고용 · 임금 · 가계,경제활동인구,27717.9,202102,천명
# 고용 · 임금 · 가계,취업자수,26364.6,202102,천명
# 고용 · 임금 · 가계,실업률,4.9,202102,%
# 고용 · 임금 · 가계,고용률,58.6,202102,%
# 고용 · 임금 · 가계,시간당명목임금증감률(전년동기대비),1.732443,202003,%
# 고용 · 임금 · 가계,노동생산성증감률(전년동기대비),4.639075,202003,%
# 고용 · 임금 · 가계,단위노동비용증감률(전년동기대비),-2.847947,202003,%
# 고용 · 임금 · 가계,가구당월평균소득,5732310.914,202004,원
# 통화 · 금융,M1(협의통화, 평잔),1183360.4,202101,십억원
# 통화 · 금융,M2(광의통화, 평잔),3224183.8,202101,십억원
# 통화 · 금융,Lf(평잔),4508736,202101,십억원
# 통화 · 금융,L(말잔),5717960.4,202101,십억원
# 통화 · 금융,예금은행총예금(평잔),1677621.6,202101,십억원
# 통화 · 금융,예금은행대출금(평잔),1903235.8,202101,십억원
# 통화 · 금융,가계신용,1726091.2826,202004,십억원
# 통화 · 금융,가계대출연체율,0.2,202012,%
# 금리,기준금리,0.5,20210225,연%
# 금리,콜금리(익일물),0.48,20210326,연%
# 금리,KORIBOR(3개월),0.76,20210329,연%
# 금리,CD수익률(91일),0.75,20210326,연%
# 금리,통안증권수익률(364일),0.664,20210326,연%
# 금리,국고채수익률(3년),1.117,20210326,연%
# 금리,국고채수익률(5년),1.532,20210326,연%
# 금리,회사채수익률(3년,AA-),2.059,20210326,연%
# 금리,예금은행 수신금리,0.87,202101,연%
# 금리,예금은행 대출금리,2.72,202101,연%
# 금리,LIBOR(U$, 3개월),0.18838,202102,연%
# 금리,미국국채수익률(10년),1.4049,202102,연%
# 증권,코스피,3041.01,20210326,1980.01.04=100
# 증권,코스닥지수,956.7,20210326,1996.07.01=1000
# 증권,주식거래대금,529556443855,202101,천원
# 증권,고객예탁금,63858500,202102,백만원
# 증권,채권거래대금,165773050,202008,없음
# 증권,국고채발행액,15327,202101,십억원
# 물가,소비자물가지수,107,202102,2015=100
# 물가,농산물 및 석유류제외 소비자물가지수,106.75,202102,2015=100
# 물가,생활물가지수,107.62,202102,2015=100
# 물가,생산자물가지수,105.85,202102,2015=100
# 물가,수출물가지수,97.83,202102,2015=100
# 물가,수입물가지수,105.53,202102,2015=100
# 물가,주택매매가격지수,108.060301,202102,2017.11=100
# 물가,주택전세가격지수,102.777171,202102,2017.11=100
# 물가,지가변동률(전기대비),0.311,202101,%
# 물가,국제유가(Dubai, 현물),63.06,202102,U$/bbl
# 국제수지 · 대외거래,경상수지,7060,202101,백만달러
# 국제수지 · 대외거래,금융계정,5280.6,202101,백만달러
# 국제수지 · 대외거래,대외채무,542448.4,202004,백만달러
# 국제수지 · 대외거래,직접투자(자산),2197.2,202101,백만달러
# 국제수지 · 대외거래,직접투자(부채),567.3,202101,백만달러
# 국제수지 · 대외거래,수출금액지수,110.32,202101,2015=100
# 국제수지 · 대외거래,수입금액지수,123.5,202101,2015=100
# 국제수지 · 대외거래,순상품교역조건지수,96,202101,2015=100
# 환율 · 외환보유,원/달러 환율(매매기준율),1131.8,20210329,원
# 환율 · 외환보유,원/달러 환율(종가),1129.3,20210326,원
# 환율 · 외환보유,원/위안 환율(매매기준율),173.02,20210329,원
# 환율 · 외환보유,원/위안 환율(종가),172.63,20210326,원
# 환율 · 외환보유,원/엔(100엔) 환율,1030.92,20210329,원
# 환율 · 외환보유,원/유로 환율,1334.28,20210329,원
# 환율 · 외환보유,외환보유액,447557482,202102,천달러
# 경제관련 사회통계,추계인구,51821669,2021,명
# 경제관련 사회통계,고령인구비율(65세 이상),16.5,2021,%
# 경제관련 사회통계,합계출산율,0.84,2020,명
# 경제관련 사회통계,자동차등록대수,24482520,202102,대
# 경제관련 사회통계,주택보급률,104.8,2019,%
# 경제관련 사회통계,지니계수,0.339,2019,없음

# %%
# naver openapi blog
import urllib.request
import json
client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = '수능'
encText = urllib.parse.quote_plus(query)
num = 100
naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=' + encText + '&display=' + str(num)

request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 블로그 글 ]')
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'])
        print ('[' + data['description'] + ']')
        count += 1
else:
    print('오류 코드 : ' + rescode)

# %%
# naver openapi blog
import urllib.request
import json

client_key = 'izGsqP2exeThwwEUVU3x'
client_secret = 'WrwbQ1l6ZI'
query = 'tns'
encText = urllib.parse.quote_plus(query)

num = 100
naver_url = 'https://openapi.naver.com/v1/search/news.json?query=' + encText + '&display=' + str(num)

request = urllib.request.Request(naver_url)
request.add_header("X-Naver-Client-Id",client_key)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

rescode = response.getcode()

if(rescode == 200):
    response_body = response.read()
    dataList = json.loads(response_body)
    count = 1
    print('[' + query + '에 대한 네이버 뉴스 글 ]')
    for data in dataList['items'] :
        print (str(count) + ' : ' + data['title'])
        print ('[' + data['description'] + ']')
        count += 1
else:
    print('오류 코드 : ' + rescode)
# Out:
# {'lastBuildDate': 'Mon, 29 Mar 2021 16:11:25 +0900',
#  'total': 42433,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '에어프랑스, 2021 고객 관계 어워드 수상 했다.',
#    'originallink': 'http://www.discoverynews.kr/378002',
#    'link': 'http://www.discoverynews.kr/378002',
#    'description': '베어링포인트와 칸타 <b>TNS</b> 가 주관하는 고객 관리 어워드는고객의 목소리를 반영하는 기업에게 수여하는 상으로 각\xa0 기업의 고객 관계를 구성하는 실행, 연결, 감정 세가지 부분 15가지 기준에 대해 고객 설문을 진행... ',
#    'pubDate': 'Thu, 25 Mar 2021 14:18:00 +0900'},
#   {'title': '에어프랑스, 6년 연속 ‘고객 관계 어워드’ 수상',
#    'originallink': 'http://www.newsway.co.kr/news/view?tp=1&ud=2021032511145072339',
#    'link': 'http://www.newsway.co.kr/news/view?tp=1&ud=2021032511145072339',
#    'description': '한편 베어링포인트와 칸타 <b>TNS</b> 가 주관하는 고객 관리 어워드는 고객의 목소리를 반영하는 기업에게 수여하는 상으로 각 기업의 고객 관계를 구성하는 실행 및 연결, 감정 세 가지 부문 15 가지 기준에 대해 고객... ',
#    'pubDate': 'Thu, 25 Mar 2021 11:17:00 +0900'},
#   {'title': "강아지 유산균 '리브펫', 반려동물 장 건강에 도움",
#    'originallink': 'http://www.kdfnews.com/news/articleView.html?idxno=71945',
#    'link': 'http://www.kdfnews.com/news/articleView.html?idxno=71945',
#    'description': '리브펫 관계자는 &quot;HACCP 인증을 받은 국내 제조시설에서 만들어진 제품이며 화학첨가물이 함유 되지 않은 제품&quot;이라며, &quot;분말 <b>TNS</b> 공법을 사용하여 소화 및 영양 흡수가 용이하다&quot;라고 전했다. 민강인 기자',
#    'pubDate': 'Wed, 24 Mar 2021 14:57:00 +0900'},
#   {'title': '값비싼 투명교정기, 국산으로 대중화 이끈다...덴티스, 글로벌 기업에 도전장',
#    'originallink': 'https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021032209443164169',
#    'link': 'https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021032209443164169',
#    'description': '지난해 1월에는 치과 전문의 장원건 원장과 함께 투명교정 전문 자회사 <b>TNS</b>(티에네스, 지분율 62%)를 설립했으며, 같은해 11월 GMP 인증, 12월 의료기기 2등급 인증을 받기도 했습니다. 덴티스는 외국산 제품보다 30% 가량... ',
#    'pubDate': 'Mon, 22 Mar 2021 10:08:00 +0900'},
#   {'title': '인터뷰 / 박성곤 하나로티엔에스 대표이사',
#    'originallink': 'http://www.klnews.co.kr/news/articleView.html?idxno=300833',
#    'link': 'http://www.klnews.co.kr/news/articleView.html?idxno=300833',
#    'description': '이 같은 비대면화에 따른 시장 급변으로 하나로<b>TNS</b>는 올해를 향후 10년 물류시장 선도를 위해 도약과 혁신... 하나로<b>TNS</b>의 전략이다. Q: 대표님이 생각하시는 글로벌 물류시장의 시장 변화 요인은 무엇이며... ',
#    'pubDate': 'Fri, 19 Mar 2021 09:45:00 +0900'},
#   {'title': "[건설사 돋보기]친환경 기업 전환 나선 SK건설, '변신통' 우려도…",
#    'originallink': 'http://www.mediapen.com/news/view/610411',
#    'link': 'http://www.mediapen.com/news/view/610411',
#    'description': '또 지난 1월 종속회사 SK <b>TNS</b>의 지분을 2900억원에 알케미스트캐피탈코리아로 매각하고, SK <b>TNS</b> 경영을 위해 설립된 투자목적회사에 600억원을 출자하기로 했다. 이 거래로 2300억원의 현금을 확보하게 된다.... ',
#    'pubDate': 'Thu, 18 Mar 2021 11:02:00 +0900'},
#   {'title': "'보행자 우선·첨단 신호' 창원 스마트 교통체계 주목",
#    'originallink': 'http://www.gimhaenews.co.kr/news/articleView.html?idxno=36538',
#    'link': 'http://www.gimhaenews.co.kr/news/articleView.html?idxno=36538',
#    'description': "시는 동림<b>TNS</b>와 4개월 간 효과를 살펴봤다. 평가는 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부' 등 4가지 항목으로 진행됐다. 평가 결과, 평일 죽곡로의 경우... ",
#    'pubDate': 'Tue, 16 Mar 2021 18:18:00 +0900'},
#   {'title': "&quot;이순신 장군의 '23전 23승' 신화는 근거 없는 거짓&quot;...사실은 이랬다",
#    'originallink': 'https://www.insight.co.kr/news/329358',
#    'link': 'https://www.insight.co.kr/news/329358',
#    'description': "한편 국내 최초의 해전드라마 '불멸의 이순신'은 방송되는 1년 동안 가구 평균 시청률 21%(<b>TNS</b> 미디어코리아)을 기록하며 꾸준히 인기를 끌었다.옥포해전을 그린 방송분은 당시 독도 문제와 맞물리면서 시청률 30%를... ",
#    'pubDate': 'Tue, 16 Mar 2021 15:20:00 +0900'},
#   {'title': '(사)인문의향기, ㈜금강<b>TNS</b>와 음식물류 폐기물 저감을 위한 생활문화운동 협약',
#    'originallink': 'http://www.incheonnews.com/news/articleView.html?idxno=401102',
#    'link': 'http://www.incheonnews.com/news/articleView.html?idxno=401102',
#    'description': '금강<b>TNS</b>, 음식물 쓰레기 저감을 위한 다양한 프로그램 도입, 시민과 함께 하는 생활문화운동 후원 인문의향기(이사장 모강인)는 음식폐기물감량기를 개발, 공급하는 (주)금강<b>TNS</b>(대표 함찬혁)와 음식물류 폐기물 저감을 위한... ',
#    'pubDate': 'Wed, 10 Mar 2021 15:15:00 +0900'},
#   {'title': '올해 건설사 주주총회 키워드는 ‘신사업’…사명변경부터 사외이사 다각화까...',
#    'originallink': 'http://www.fntimes.com/html/view.php?ud=2021031009473979775e6e69892f_18',
#    'link': 'http://www.fntimes.com/html/view.php?ud=2021031009473979775e6e69892f_18',
#    'description': '또 올해 SK건설은 사모펀드(PEF) 운용사 ‘알케미스트캐피탈파트너스코리아’에 자회사인 ‘SK <b>TNS</b>’를 2900억 원에 매각하기도 했다. 같은 날에는 삼성물산 역시 주주총회를 연다. 지난해 임원인사에서 삼성물산... ',
#    'pubDate': 'Wed, 10 Mar 2021 09:53:00 +0900'},
#   {'title': "[금일 증권업계 주요기사] 국민연금, 리밸런싱에 동학개미 '부글부글'…유가 ...",
#    'originallink': 'http://www.youthdaily.co.kr/news/article.html?no=64645',
#    'link': 'http://www.youthdaily.co.kr/news/article.html?no=64645',
#    'description': 'SK건설은 자회사 SK <b>TNS</b>를 사모펀드(PEF)에 팔았음. SKC는 2019년 인수한 SK넥실리스(전 KCFT)의 말레이시아 공장 설립 자금을 자본시장에서 조달할 가능성이 거론된다고. SK와 SK E&amp;S는 플러그파워를 인수했는데, 투자 물량... ',
#    'pubDate': 'Tue, 09 Mar 2021 18:20:00 +0900'},
#   {'title': '[Invest]실탄 마련이 곧 실적...유동성 블랙홀 된 SK그룹',
#    'originallink': 'http://www.investchosun.com/?p=3258985',
#    'link': 'http://www.investchosun.com/?p=3258985',
#    'description': 'SK건설은 자회사 SK <b>TNS</b>를 사모펀드(PEF)에 팔았다. SKC는 2019년 인수한 SK넥실리스(전 KCFT)의 말레이시아 공장 설립 자금을 자본시장에서 조달할 가능성이 거론된다. SK㈜와 SK E&amp;S는 플러그파워를 인수했는데, 투자 물량... ',
#    'pubDate': 'Tue, 09 Mar 2021 07:09:00 +0900'},
#   {'title': '포스코, 육상전원공급설비로 대기질 개선 동참',
#    'originallink': 'http://www.ksmnews.co.kr/default/index_view_page.php?idx=326590&part_idx=234',
#    'link': 'http://www.ksmnews.co.kr/default/index_view_page.php?idx=326590&part_idx=234',
#    'description': '유성<b>TNS</b> 대표이사 등이 참석한 가운데 &lt;친환경 선박 육상전원공급설비 가동식&gt;을 가졌다.기존에는 부두에... 유성<b>TNS</b>와 함께 설비 설치 및 활용도 제고를 위한 업무협약을 맺었다. 이후 1년여 기간 동안... ',
#    'pubDate': 'Mon, 08 Mar 2021 22:08:00 +0900'},
#   {'title': '포스코-평택해수청, 육상전원공급설비로 항만 미세먼지 줄인다',
#    'originallink': 'http://www.idaegu.co.kr/news/articleView.html?idxno=339747',
#    'link': 'http://www.idaegu.co.kr/news/articleView.html?idxno=339747',
#    'description': "유성<b>TNS</b> 대표이사 등이 참석한 가운데 '친환경 선박 육상전원공급설비 가동식'을 가졌다. 기존에는 부두에... 유성<b>TNS</b>와 함께 설비 설치 및 활용도 제고를 위한 업무협약을 맺었다. 이후 1년여 기간 동안... ",
#    'pubDate': 'Mon, 08 Mar 2021 17:44:00 +0900'},
#   {'title': '포스코-평택해수청, 육상전원공급설비로 대기오염 물질 15t 줄인다',
#    'originallink': 'http://www.hellot.net/new_hellot/magazine/magazine_read.html?code=201&sub=004&idx=56944',
#    'link': 'http://www.hellot.net/new_hellot/magazine/magazine_read.html?code=201&sub=004&idx=56944',
#    'description': '유성<b>TNS</b>와 함께 설비 설치 및 활용도 제고를 위한 업무협약을 맺었다. 이후 1년여 기간 동안 평택지방해양수산청과 선사는 육상전원공급설비와 선박 내 수전(受電)설비 설치를 각각 완료했고, 한 달간의 안전점검 및... ',
#    'pubDate': 'Mon, 08 Mar 2021 14:03:00 +0900'},
#   {'title': '포스코·평택해수청, 친환경 선박 육상전원공급설비로 항만 미세먼지 줄인다',
#    'originallink': 'http://digitalchosun.dizzo.com/site/data/html_dir/2021/03/08/2021030880024.html',
#    'link': 'http://digitalchosun.dizzo.com/site/data/html_dir/2021/03/08/2021030880024.html',
#    'description': '유성<b>TNS</b>와 함께 설비 설치 및 활용도 제고를 위한 업무협약을 맺었다. 이후 1년여 기간 동안 평택지방해양수산청과 선사는 육상전원공급설비와 선박 내 수전(受電)설비 설치를 각각 완료했고, 한 달간의 안전점검 및... ',
#    'pubDate': 'Mon, 08 Mar 2021 09:20:00 +0900'},
#   {'title': '하나로<b>TNS</b>, 정기인사·조직개편 단행',
#    'originallink': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=129494',
#    'link': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=129494',
#    'description': '하나로<b>TNS</b>가 3월1일자로 정기인사와 조직개편을 단행했다. 이번 조직 개편은 급변하는 물류기술 개발과 운영 연구를 위한 물류연구소의 위상을 강화하고 분산되었던 국내 3PL 물류 조직을 재편해 3실, 9개 사업부... ',
#    'pubDate': 'Mon, 08 Mar 2021 09:10:00 +0900'},
#   {'title': '포스코-평택해수청, 육상전원공급설비로 항만 미세먼지 줄인다',
#    'originallink': 'http://www

#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004595620',
#    'description': "유성<b>TNS</b> 대표이사 등이 참석한 가운데 '친환경 선박 육상전원공급설비 가동식'을 열었다. 기존에는 부두에... 유성<b>TNS</b>와 함께 설비 설치 및 활용도 제고를 위한 업무협약을 맺었다. 이후 1년여 기간 동안... ",
#    'pubDate': 'Fri, 05 Mar 2021 15:00:00 +0900'},
#   {'title': '하나로<b>TNS</b>, 물류 역량 강화 위한 조직개편 나서 \xa0',
#    'originallink': 'http://www.klnews.co.kr/news/articleView.html?idxno=300677',
#    'link': 'http://www.klnews.co.kr/news/articleView.html?idxno=300677',
#    'description': '하나로<b>TNS</b>(대표이사 박성곤)가 3월 1일 자로 정기인사 및 조직개편을 단행했다. 이번 조직 개편의 주요... 이번 하나로<b>TNS</b>의 주요 승진명단은 다음과 같다. △이사 권주석 △수석부장 임형진 △부장 이세원, 김승민, 손병성... ',
#    'pubDate': 'Fri, 05 Mar 2021 11:27:00 +0900'},
#   {'title': "'상의 회장' 최태원, 재계 대표·그룹 경영 등 시험대",
#    'originallink': 'http://www.ftoday.co.kr/news/articleView.html?idxno=211883',
#    'link': 'http://www.ftoday.co.kr/news/articleView.html?idxno=211883',
#    'description': '야구단인 SK와이번스를 신세계에 매각했고, SK <b>TNS</b>, SK루브리컨츠, SK종합화학 등의 지분을 정리했다. 지주사 SK는 지난달 24일 SK바이오팜 지분 약 11%를 블록딜(시간 외 대량매매) 방식으로 매각해 1조1163억원을 확보했다.... ',
#    'pubDate': 'Thu, 04 Mar 2021 15:17:00 +0900'},
#   {'title': '[인터뷰] &quot;리테일 운명, 물류와 배송이 좌우”',
#    'originallink': 'http://www.apparelnews.co.kr/news/news_view/?idx=188724',
#    'link': 'http://www.apparelnews.co.kr/news/news_view/?idx=188724',
#    'description': '개발사 선경개발, 시공사 선경이앤씨, 국내 물류 설비 1위 보우시스템, 운영과 배송의 로지스밸리(천마, SLK 등), 하나로<b>TNS</b> 등이 소속돼 있다. 쿠팡 ‘로켓배송’ 기획부터 투자까지 로지스, 6개월 만에 풀필먼트 인프라... ',
#    'pubDate': 'Thu, 04 Mar 2021 00:06:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27곳 운영 효과봤다',
#    'originallink': 'https://www.nocutnews.co.kr/news/5508175',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003473712',
#    'description': "효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다. 평가 결과, 평일... ",
#    'pubDate': 'Mon, 01 Mar 2021 20:13:00 +0900'},
#   {'title': '[K-Biz 리뷰] 中BYD, 현대차 배터리 공급 추진·일론 머스크, 사이버트럭 최종...',
#    'originallink': 'https://www.theguru.co.kr/news/article.html?no=19220',
#    'link': 'https://www.theguru.co.kr/news/article.html?no=19220',
#    'description': "고소 ▲ 현대자동차 =\xa0밍투EV 내달 1일 中 출격…권토중래 노린다 ▲ 현대중공업·대우조선해양 = '1.9조' 페트로브라스 해양플랜트 첫 관문 통과…삼성重 탈락 ▲ 효성<b>TNS</b> = 신규 고객 캠페인 전개…&quot;영감 주는 경험 선사&quot;",
#    'pubDate': 'Sun, 28 Feb 2021 05:01:00 +0900'},
#   {'title': '[K-Biz 리뷰] 美대마초 펀드 운용자산 규모, 반년새 400배 늘어(2월27일)',
#    'originallink': 'https://www.theguru.co.kr/news/article.html?no=19219',
#    'link': 'https://www.theguru.co.kr/news/article.html?no=19219',
#    'description': "고소 ▲ 현대자동차 =\xa0밍투EV 내달 1일 中 출격…권토중래 노린다 ▲ 현대중공업·대우조선해양 = '1.9조' 페트로브라스 해양플랜트 첫 관문 통과…삼성重 탈락 ▲ 효성<b>TNS</b> = 신규 고객 캠페인 전개…&quot;영감 주는 경험 선사&quot;",
#    'pubDate': 'Sat, 27 Feb 2021 05:02:00 +0900'},
#   {'title': '효성<b>TNS</b>, 신규 고객 캠페인 전개…&quot;영감 주는 경험 선사&quot;',
#    'originallink': 'https://www.theguru.co.kr/news/article.html?no=19211',
#    'link': 'https://www.theguru.co.kr/news/article.html?no=19211',
#    'description': "효성<b>TNS</b>가 글로벌 웹사이트를 오픈하고 체험 센터를 마련하는 등 고객에게 영감을 주는 경험을 선사하기 위한 새로운 캠페인을 펼치고 있다. 26일 업계에 따르면 효성<b>TNS</b>는 지난 25일(현지시간) '영감을 받다(Be Inspired)... ",
#    'pubDate': 'Fri, 26 Feb 2021 15:35:00 +0900'},
#   {'title': '창원 외곽도로 감응신호 27개소 운영 효과 좋아',
#    'originallink': 'http://www.gndomin.com/news/articleView.html?idxno=269075',
#    'link': 'http://www.gndomin.com/news/articleView.html?idxno=269075',
#    'description': "효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다. 4개 항목 효과평가... ",
#    'pubDate': 'Fri, 26 Feb 2021 08:27:00 +0900'},
#   {'title': "[더벨]SK그룹의 'FI 활용' 나비효과",
#    'originallink': 'http://www.thebell.co.kr/front/free/contents/news/article_view.asp?key=202102250446244720105371',
#    'link': 'http://www.thebell.co.kr/front/free/contents/news/article_view.asp?key=202102250446244720105371',
#    'description': 'SK와이번스와 SK <b>TNS</b>, SK루브리컨츠 소수지분, SK종합화학 소수지분 등 올 들어 진행되는 매각 건만 다수다. 여기에 티맵모빌리티 투자유치, SK하이닉스의 인텔 낸드사업부 인수 등 신규사업 진출과 기존사업 강화를... ',
#    'pubDate': 'Fri, 26 Feb 2021 08:22:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영 효과 좋아',
#    'originallink': 'http://www.gnnews.co.kr/news/articleView.html?idxno=468806',
#    'link': 'http://www.gnnews.co.kr/news/articleView.html?idxno=468806',
#    'description': "효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다. 이은수기자 eunsu@gnnews.... ",
#    'pubDate': 'Fri, 26 Feb 2021 00:56:00 +0900'},
#   {'title': '창원 지능형 감응신호, 교통흐름 크게 개선 했다',
#    'originallink': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=300658',
#    'link': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=300658',
#    'description': "효과평가는 지능형 교통 체계 공모사업 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다.... ",
#    'pubDate': 'Thu, 25 Feb 2021 16:53:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27곳 교통흐름 개선',
#    'originallink': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1381667',
#    'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1381667',
#    'description': '효과평가는\xa0ITS\xa0전문 업체인 주식회사 동림<b>TNS</b>에서\xa04가지 항목인\xa0‘주방향 녹색시간 증가 여부’, ‘통행시간 감소 여부’, ‘정지지체 감소 여부’, ‘신호위반 감소 여부’를\xa04개월간 심도 있게 평가했다. 4개... ',
#    'pubDate': 'Thu, 25 Feb 2021 16:37:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영 효과 좋아',
#    'originallink': 'http://www.kndaily.co.kr/news/articleView.html?idxno=188256',
#    'link': 'http://www.kndaily.co.kr/news/articleView.html?idxno=188256',
#    'description': "효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다. 4개 항목 효과평가 결과... ",
#    'pubDate': 'Thu, 25 Feb 2021 16:22:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영···교통흐름 크게 개선',
#    'originallink': 'http://www.betanews.net:8080/article/1255921.html',
#    'link': 'http://www.betanews.net:8080/article/1255921.html',
#    'description': "효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 '주방향 녹색시간 증가 여부', '통행시간 감소 여부', '정지지체 감소 여부', '신호위반 감소 여부'를 4개월간 심도 있게 평가했다. 4개 항목 효과평가... ",
#    'pubDate': 'Thu, 25 Feb 2021 13:37:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영 효과 톡톡',
#    'originallink': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202102251244201200881',
#    'link': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202102251244201200881',
#    'description': '효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 ‘주방향 녹색시간 증가 여부’, ‘통행시간 감소 여부’, ‘정지지체 감소 여부’, ‘신호위반 감소 여부’를 4개월간 평가했다. 4개 항목 효과평가... ',
#    'pubDate': 'Thu, 25 Feb 2021 13:12:00 +0900'},
#   {'title': "[창원소식] 창원 외곽도로 감응신호 27개소 '효과 톡톡'",
#    'originallink': 'http://www.kukinews.com/newsView/kuk202102250104',
#    'link': 'http://www.kukinews.com/newsView/kuk202102250104',
#    'description': '효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 ‘주방향 녹색시간 증가 여부’, ‘통행시간 감소 여부’, ‘정지지체 감소 여부’, ‘신호위반 감소 여부’를 4개월간 심도 있게 평가했다. 4개 항목... ',
#    'pubDate': 'Thu, 25 Feb 2021 11:40:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영 효과 좋아!',
#    'originallink': 'http://www.hkbs.co.kr/news/articleView.html?idxno=618579',
#    'link': 'http://www.hkbs.co.kr/news/articleView.html?idxno=618579',
#    'description': '효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 주방향 녹색시간 증가 여부, 통행시간 감소 여부, 정지지체 감소 여부, 신호위반 감소 여부를 4개월간 심도 있게 평가했다. 4개 항목 효과평가 결과... ',
#    'pubDate': 'Thu, 25 Feb 2021 11:37:00 +0900'},
#   {'title': '창원시, 외곽도로 감응신호 27개소 운영 효과 좋아!',
#    'originallink': 'http://www.busan.com/view/busan/view.php?code=2021022510541902952',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=082&aid=0001070369',
#    'description': '효과평가는 ITS 전문업체인 주식회사 동림<b>TNS</b>에서 4가지 항목인 ‘주방향 녹색시간 증가 여부’, ‘통행시간 감소 여부’, ‘정지지체 감소 여부’, ‘신호위반 감소 여부’를 4개월간 심도 있게 평가했다. 4개 항목... ',
#    'pubDate': 'Thu, 25 Feb 2021 10:58:00 +0900'},
#   {'title': '한국국제물류협회, 정기총회 열고 원제철 신임 회장 선출',
#    'originallink': 'http://www.klnews.co.kr/news/articleView.html?idxno=300501',
#    'link': 'http://www.klnews.co.kr/news/articleView.html?idxno=300501',
#    'description': '한편 △김병진 한국국제물류협회 전 회장 △이원정 덕성여자대학교 교수 △김은비 부산항만공사 소장 △조경규 한국국제물류협회 이사 △한재동 태웅로직스 대표이사 △박성곤 하나로<b>TNS</b> 대표이사 △김창호... ',
#    'pubDate': 'Wed, 24 Feb 2021 16:07:00 +0900'},
#   {'title': '하나로<b>TNS</b>, 이형화물 택배 사업 전격 진출',
#    'originallink': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=129338',
#    'link': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=129338',
#    'description': '하나로<b>TNS</b>는 최근 비대면 시장에서 급성장하고 있는 택배사업 중 전통 택배사들이 취급을 꺼리고 있는 이형화물(Box 사이즈 160㎝ 초과, 중량 20kg 초과)에 대한 택배사업에 진출한다고 지난 19일 밝혔다. 하나로<b>TNS</b>는 고객이... ',
#    'pubDate': 'Mon, 22 Feb 2021 10:25:00 +0900'},
#   {'title': '하나로<b>TNS</b>, TPM코리아 인수해 이형화물 택배 사업 진출',
#    'originallink': 'http://www.klnews.co.kr/news/articleView.html?idxno=300466',
#    'link': 'http://www.klnews.co.kr/news/articleView.html?idxno=300466',
#    'description': '하나로<b>TNS</b>(대표 박성곤)는 기존 택배사들이 취급을 꺼리는 이형화물 택배산업에 진출한다고 밝혔다.... 하나로<b>TNS</b>는 이형화물 전문택배사인 TPM코리아(주)를 인수해 하나로<b>TNS</b>의 전국적인 물류 거점 및 우수한 물류운영... ',
#    'pubDate': 'Fri, 19 Feb 2021 15:12:00 +0900'},
#   {'title': '삼성전자로지텍 협력사 노조 &quot;단가 후려치기에 적자의 늪&quot;',
#    'originallink': 'http://www.inews24.com/view/1344069',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000584607',
#    'description': '하나로<b>TNS</b>지회 역시 파업에 동참하는 방안을 검토 중이다. 삼성전자 평택 종합물류센터는 삼성전자의... 평택 종합물류센터의 경우 하나로<b>TNS</b>가 입고 업무를, 인성지엘씨가 보관과 하역 업무를 맡고 있다. 이중... ',
#    'pubDate': 'Thu, 18 Feb 2021 16:32:00 +0900'},
#   {'title': '[IB토마토](크레딧시그널)SK건설, EMC 인수로 재무부담 확대 불가피',
#    'originallink': 'http://www.newstomato.com/ReadNews.aspx?no=1025622',
#    'link': 'http://www.newstomato.com/ReadNews.aspx?no=1025622',
#    'description': '재무부담 완화를 위해 SK건설은 TSK코퍼레이션과 SK <b>TNS</b> 지분을 각각 1969억원과 2900억원에 매각했다. 하지만 한기평에 따르면 SK건설은 환경 부문에 추가적인 사업 확대를 계획하고 있어 향후 재무 부담이 추가적으로... ',
#    'pubDate': 'Tue, 16 Feb 2021 17:18:00 +0900'},
#   {'title': '[HotJobs 100] 비즈니스피플이 엄선한 오늘의 채용-2월15일',
#    'originallink': 'http://www.businesspost.co.kr/BP?command=article_view&num=217339',
#    'link': 'http://www.businesspost.co.kr/BP?command=article_view&num=217339',
#    'description': '◆ SK <b>TNS</b>, 공인노무사 채용 인사노무관리 정책을 수립하고 근로기준을 수립하며 노사관계, 노무 이슈에 관한 법률 검토를 수행할 경력자를 채용한다. 공인노무사 자격을 보유한 사람, 노무법인 또는 법무법인에서 3년... ',
#    'pubDate': 'Mon, 15 Feb 2021 11:30:00 +0900'}]}

# %%
import tweepy

api_key = "RvnZeIl8ra88reu8fm23m0bST"
api_secret = "wTRylK94GK2KmhZUnqXonDaIszwAsS6VPvpSsIo6EX5GQLtzQo"
access_token = "959614462004117506-dkWyZaO8Bz3ZXh73rspWfc1sQz0EnDU"
access_token_secret = "rxDWfg7uz1yXMTDwijz0x90yWhDAnmOM15R6IgC8kmtTe"

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

keyword = '치맥'   
search = []   

cnt = 1
while(cnt <= 10):   
    tweets = api.search(q=keyword, count=100)
    for tweet in tweets :
        search.append(tweet)
    cnt += 1

data = {}   
i = 1   
print('[' + keyword + '에 대한 트윗 글 ]')    
for tweet in search:
    data['text'] = tweet.text   
    print(i, " : ", data)   
    i += 1

# %%
import os
import sys
import urllib.request
import datetime
import time
import json

client_id = '0LHQM4VX_MQM6JfkXofa'
client_secret = 'OcPgqpswCg'


#[CODE 1]
def getRequestUrl(url):    
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    
    try: 
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print ("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

#[CODE 2]
def getNaverSearch(node, srcText, start, display):    
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)
    
    url = base + node + parameters    
    responseDecode = getRequestUrl(url)   #[CODE 1]
    
    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

#[CODE 3]
def getPostData(post, jsonResult, cnt):    
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']
    
    pDate = datetime.datetime.strptime(post['pubDate'],  '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')
    
    jsonResult.append({'cnt':cnt, 'title':title, 'description': description, 
'org_link':org_link,   'link': org_link,   'pDate':pDate})
    return

# %%
node = 'news'   # 크롤링 할 대상
srcText = input('검색어를 입력하세요: ')
cnt = 0
jsonResult = []

jsonResponse = getNaverSearch(node, srcText, 1, 100)  #[CODE 2]
total = jsonResponse['total']
 
while ((jsonResponse != None) and (jsonResponse['display'] != 0)):         
    for post in jsonResponse['items']:
        cnt += 1
        getPostData(post, jsonResult, cnt)  #[CODE 3]       
        
    start = jsonResponse['start'] + jsonResponse['display']
    jsonResponse = getNaverSearch(node, srcText, start, 100)  #[CODE 2]
       
print('전체 검색 : %d 건' %total)
    
with open('output/%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
    jsonFile = json.dumps(jsonResult,  indent=4, sort_keys=True,  ensure_ascii=False)
                        
    outfile.write(jsonFile)
        
print("가져온 데이터 : %d 건" %(cnt))
print ('output/%s_naver_%s.json SAVED' % (srcText, node))

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import datetime

#[CODE 1]
def hollys_store(result):
    for page in range(1,59):
        Hollys_url = 'https://www.hollys.co.kr/store/korea/korStore.do?pageNo=%d&sido=&gugun=&store=' %page
        print(Hollys_url)
        html = urllib.request.urlopen(Hollys_url)
        soupHollys = BeautifulSoup(html, 'html.parser')
        tag_tbody = soupHollys.find('tbody')
        for store in tag_tbody.find_all('tr'):
            if len(store) <= 3:
                break
            store_td = store.find_all('td')
            store_name = store_td[1].string
            store_sido = store_td[0].string
            store_address = store_td[3].string
            store_phone = store_td[5].string
            result.append([store_name]+[store_sido]+[store_address]
                          +[store_phone])
    return

#[CODE 0]
result = []
print('Hollys store crawling >>>>>>>>>>>>>>>>>>>>>>>>>>')
hollys_store(result)   #[CODE 1] 호출 
hollys_tbl = pd.DataFrame(result, columns=('store', 'sido-gu', 'address','phone'))
hollys_tbl.to_csv('output/hollys.csv', encoding='cp949', mode='w', index=True) # cp949 - euc-kr
del result[:]
# Out:
# Hollys store crawling >>>>>>>>>>>>>>>>>>>>>>>>>>
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=1&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=2&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=3&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=4&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=5&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=6&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=7&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=8&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=9&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=10&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=11&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=12&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=13&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=14&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=15&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=16&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=17&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=18&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=19&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=20&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=21&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=22&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=23&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=24&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=25&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=26&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=27&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=28&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=29&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=30&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=31&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=32&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=33&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=34&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=35&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=36&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=37&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=38&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=39&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=40&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=41&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=42&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=43&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=44&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=45&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=46&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=47&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=48&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=49&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=50&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=51&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=52&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=53&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=54&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=55&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=56&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=57&sido=&gugun=&store=
# https://www.hollys.co.kr/store/korea/korStore.do?pageNo=58&sido=&gugun=&store=

# %%
# 완료하는데 시간이 오래걸린다.
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import datetime

from selenium import webdriver
import time

#[CODE 1]
def CoffeeBean_store(result):
    CoffeeBean_URL = "https://www.coffeebeankorea.com/store/store.asp"
    wd = webdriver.Chrome('c:/Temp/chromedriver.exe')
             
    for i in range(1, 370):  #매장 수 만큼 반복
        wd.get(CoffeeBean_URL)
        time.sleep(1)  #웹페이지 연결할 동안 1초 대기
        try:
            wd.execute_script("storePop2(%d)" %i)
            time.sleep(1) #스크립트 실행 할 동안 1초 대기
            html = wd.page_source
            soupCB = BeautifulSoup(html, 'html.parser')
            store_name_h2 = soupCB.select("div.store_txt > h2")
            store_name = store_name_h2[0].string
            print(store_name)  #매장 이름 출력하기
            store_info = soupCB.select("div.store_txt > table.store_table > tbody > tr > td")
            store_address_list = list(store_info[2])
            store_address = store_address_list[0]
            store_phone = store_info[3].string
            result.append([store_name]+[store_address]+[store_phone])
        except:
            continue 
    return

result = []
print('CoffeeBean store crawling >>>>>>>>>>>>>>>>>>>>>>>>>>')
CoffeeBean_store(result)  #[CODE 1]
    
CB_tbl = pd.DataFrame(result, columns=('store', 'address','phone'))
CB_tbl.to_csv('output/CoffeeBean.csv', encoding='cp949', mode='w', index=True)
